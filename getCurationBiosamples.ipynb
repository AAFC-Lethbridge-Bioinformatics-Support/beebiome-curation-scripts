# %% [markdown]
# ### Beebiome curation script
# Using the new file with all non Apoidea genera (generaFilter)
#
# Two text files were downloaded from NCBI, one for all genera and one for the Apoidea genera only. Entries in the Apoidea genera file were then substracted from the all genera file. This new file will help to automatically identify records in the XMLs which are non Apoidea and set the flag to "autoNoG". This will make the number of rows to check smaller and simplify the next curation steps by focusing only on records which might have an Apoidea host.
#
# The curation works in 2 steps:
#
#     - drop1 will convert all biosample XML files to CSV, then delete all records with hosts in nonApoidea genera and save as *Drop1.csv;
#
#     - drop2 will check if host is on the white list and update the taxid, then save to *Drop2.csv and save to one file all the result files.
#
# LM, 14/MAR/2022

# %%
#init
import sys, os, re, datetime
import xmltodict, pathlib, glob
import pandas as pd

dnIn = '\\Apoidea2Mar22\\' # Set the data directory
dnIn = os.path.normpath(dnIn)
print('Start time: ' + str(datetime.datetime.now()))
print("-Apoidea folder: " + dnIn)
    
dnWork = os.getcwd() # Set the working directory
dn, dName  = os.path.split(dnWork)

dnOut = dnIn + '\\biosample_XMLtoCSVs\\' # Set the output folder
if not os.path.exists(dnOut): os.makedirs(dnOut)

whiteL = pd.read_csv(dnWork + '\\host_white_list.csv')
whiteL["host"] = whiteL["host"].str.lower()
nonApoideaGenera = pd.read_csv(dnWork + '\\genera_not_apoidea.txt', header=None)
beta_data = pd.read_csv(dnWork + '\\in-beta_9Mar22.csv')
auto_no = pd.read_csv(dnWork + '\\auto-no.csv')
auto_no = [str(x) for x in auto_no['autoNo if host in'].tolist()]
auto_no = [x.casefold() for x in auto_no]
auto_no = "(" + ")|(".join(auto_no) + ")"
useCSV = 1

def dfInit(df):
    df['has_proj'] = pd.Series(['' for x in range(len(df.index))])
    col = df.pop('has_proj')
    df.insert(0, col.name, col)
    df['has_sra'] = pd.Series(['' for x in range(len(df.index))])
    col = df.pop('has_sra')   
    df.insert(0, col.name, col)
    df['load'] = pd.Series(['' for x in range(len(df.index))])
    col = df.pop('load')
    df.insert(0, col.name, col)
    df['in_beta'] = pd.Series(['' for x in range(len(df.index))])
    col = df.pop('in_beta')
    df.insert(0, col.name, col)
    df['taxid'] = pd.Series(['' for x in range(len(df.index))])
    col = df.pop('taxid')
    df.insert(0, col.name, col)
    df['host'] = pd.Series(['' for x in range(len(df.index))])
    col = df.pop('host')
    df.insert(0, col.name, col)
    return df

def getHost(listItems):
    # Find the host name and return it if exists, if no return None 
    name = 'None'
    if type(listItems) != 'list':
        i1 = listItems
        if '@attribute_name' in i1:
            if i1['@attribute_name'] == 'host':            
                name = i1['#text'] #print('yess one')
            return name
    for i1 in listItems:
        if '@attribute_name' in i1:
            if i1['@attribute_name'] == 'host':            
                name = i1['#text']
                break
    return name

def getProj(listItems):
    # Find the project name and return it if exists, if no return None 
    name = 'None'
    #print(type(listItems.items())) #print(sys.getsizeof(listItems.items()))
    if type(listItems) != 'list':
        i1 = listItems
        if '@target' in i1:
            if i1['@target'] == 'bioproject':            
                name = i1['@label']
            return name
    for i1 in listItems:
        #print(i1.keys())
        if '@target' in i1:
            if i1['@target'] == 'bioproject':            
                name = i1['@label']
                break
    return name

def getSRA(listItems):
    # Find the SRA acc. and return it if exists, if no return None 
    name = 'None'
    if type(listItems) != 'list':
        i1 = listItems
        if '@db' in i1:
            if i1['@db'] == 'SRA':            
                name = i1['#text']
            return name
    for i1 in listItems:
        #print(i1.keys())
        if '@db' in i1:
            if i1['@db'] == 'SRA':            
                name = i1['#text']
                break
    return name
# Out:
# Start time: 2022-03-14 17:35:38.632920
# -Apoidea folder: D:\arh2021\_poGc21\bPortal\Apoidea2Mar22

# %%
# Step Drop1, save XML files to CSV

listF = list(pathlib.Path(dnIn).glob('*.xml'))
for f_name in listF:
        dn0, fn0  = os.path.split(f_name)
        if (fn0.startswith('Apoidea_biosample.9')) and os.path.getsize(f_name) > 0: #.2.
                #print(f_name)
                fnIn = dnIn + '\\' + fn0
                fnOut = fn0.replace('.', '_')
                fn = open(fnIn); fn.seek(0); xml = fn.read() #read xml file
                dsdocs = xmltodict.parse(xml) #convert xml to python dict
                df = pd.DataFrame(dsdocs ['BioSampleSet']['BioSample'])
                s0=len(df.index)
                print('--Processing: ' + fn0 + '  biosamples:' + str(s0))
                dfIndDrop = []
                df = dfInit(df) #add 6 columns with flags

                #for row in df.itertuples(name='row'):   print(row) might be faster
                for index, row0 in df.iterrows():
                        row = row0
                        strSkip = ''
                        row['load'] = ''
                        row['taxid'] = ''
                        row['in_beta'] = ''
                        row['host'] = getHost(row['Attributes']['Attribute'])
                        str1 = row['host'] #print(str1)
                        if type(str1) != str: print(index, str1) #host name is a number??continue
                        value = str1.split()[0]
                        if nonApoideaGenera.isin([value]).any().any() or (len(str1) < 3) or str1.lower()=='n/a': 
                                #check if value exist in nonApoideaGenera, then drop
                                row['load'] = 'autoNoG'    #print(value + ' autoNoG')
                                row['taxid'] = 'NotApoidea'
                                row['in_beta'] = 'inBetaN/A'
                                strSkip = 'In nonApoideaGenera, skip'
                        if re.match(auto_no, str1.casefold()): 
                                #check if host exist in autoNo (black list), then drop
                                if row['in_beta'] == 'inBeta': print('Warning!!!')
                                #if row['host'] == 'Ceratina':  print('Warning!!!'); break
                                row['load'] = 'autoNoSkip'
                                row['taxid'] = 'NotApoidea'
                                row['in_beta'] = 'inBetaN/A'
                                strSkip = 'On black list, skip' #continue
                        row['has_sra'] = getSRA(row['Ids']['Id'])
                        try:
                                row['has_proj'] = getProj(row['Links']['Link']) #break
                        except:
                                row['has_proj'] = 'None' #print('no2')
                        if row['@accession'] in beta_data.loc[:,"BioSample acc"].values: 
                                #if inBeta, skip
                                row['in_beta'] = 'inBetaYes'
                                row['load'] = 'inBeta'
                                strSkip = 'In beta, skip'
                        elif row['load'] == '':
                                row['in_beta'] = 'inBetaNo'
                                row['load'] = 'Load'
                                row['taxid'] = 'Load2'
                                strSkip = 'Load2'
                                if row['has_sra'] == 'None':
                                        row['load'] = 'autoNoSRA'
                                        strSkip = 'autoNoSRA, skip'
                        # set taxid if in the host_white_list 
                        v1 = whiteL.loc[whiteL['host'] == str1.casefold()]
                        v2 = v1['taxid'].tolist()
                        if v2: # != 'None': #row['host'] in host_white_list.loc[:,"host"].values:
                                row['taxid'] = str(v2[0])                     
                        if row['load'] != 'Load': 
                                dfIndDrop.append(index)
                        #os.system('cls')
                        print(fn0 + ' ==> ' + str(index + 1) + '/' + str(s0) + '    ', row['host'],row['in_beta'],row['load'],row['has_sra'],row['has_proj'],strSkip)
                        row0 = row
                df.to_csv(dnOut + fnOut + 'L.csv', encoding='utf-8', index=False) 
                df.drop(dfIndDrop, inplace=True)
                df.to_csv(dnOut + fnOut + 'Drop.csv', encoding='utf-8', index=False) 
#import ctypes ctypes.windll.user32.MessageBoxW(0, "Done step1", "Processing", 1)
print('Drop1 done.') #print('End time: ' + str(datetime.datetime.now()))
# Out:
# --Processing: Apoidea_biosample.9.xml  biosamples:161
# Apoidea_biosample.9.xml ==> 1/161     Oryza sativa cv. BPT5209 inBetaN/A autoNoSkip SRS11686923 PRJNA797556 On black list, skip
# Apoidea_biosample.9.xml ==> 2/161     Oryza sativa cv. BPT5208 inBetaN/A autoNoSkip SRS11686922 PRJNA797556 On black list, skip
# Apoidea_biosample.9.xml ==> 3/161     Oryza sativa cv. BPT5207 inBetaN/A autoNoSkip SRS11686921 PRJNA797556 On black list, skip
# Apoidea_biosample.9.xml ==> 4/161     Oryza sativa cv. BPT5206 inBetaN/A autoNoSkip SRS11686920 PRJNA797556 On black list, skip
# Apoidea_biosample.9.xml ==> 5/161     Oryza sativa cv. BPT5205 inBetaN/A autoNoSkip SRS11686919 PRJNA797556 On black list, skip
# Apoidea_biosample.9.xml ==> 6/161     Oryza sativa cv. BPT5204 inBetaN/A autoNoSkip SRS11686918 PRJNA797556 On black list, skip
# Apoidea_biosample.9.xml ==> 7/161     Hymenoptera: Apidae inBetaN/A autoNoSkip SRS9464940 PRJNA744643 On black list, skip
# Apoidea_biosample.9.xml ==> 8/161     Meliponula sp. inBetaNo Load SRS10787304 None Load2
# Apoidea_biosample.9.xml ==> 9/161     Meliponula sp. inBetaNo Load SRS10787303 None Load2
# Apoidea_biosample.9.xml ==> 10/161     Meliponula sp. inBetaNo Load SRS10787302 None Load2
# Apoidea_biosample.9.xml ==> 11/161     Meliponula sp. inBetaNo Load SRS10787347 None Load2
# Apoidea_biosample.9.xml ==> 12/161     Meliponula sp. inBetaNo Load SRS10787301 None Load2
# Apoidea_biosample.9.xml ==> 13/161     Meliponula sp. inBetaNo Load SRS10787356 None Load2
# Apoidea_biosample.9.xml ==> 14/161     Meliponula sp. inBetaNo Load SRS10787354 None Load2
# Apoidea_biosample.9.xml ==> 15/161     Meliponula sp. inBetaNo Load SRS10787353 None Load2
# Apoidea_biosample.9.xml ==> 16/161     Meliponula sp. inBetaNo Load SRS10787352 None Load2
# Apoidea_biosample.9.xml ==> 17/161     Meliponula sp. inBetaNo Load SRS10787351 None Load2
# Apoidea_biosample.9.xml ==> 18/161     Meliponula sp. inBetaNo Load SRS10787350 None Load2
# Apoidea_biosample.9.xml ==> 19/161     Meliponula sp. inBetaNo Load SRS10787349 None Load2
# Apoidea_biosample.9.xml ==> 20/161     Meliponula sp. inBetaNo Load SRS10787348 None Load2
# Apoidea_biosample.9.xml ==> 21/161     Meliponula sp. inBetaNo Load SRS10787305 None Load2
# Apoidea_biosample.9.xml ==> 22/161     Meliponula sp. inBetaNo Load SRS10787316 None Load2
# Apoidea_biosample.9.xml ==> 23/161     Meliponula sp. inBetaNo Load SRS10787317 None Load2
# Apoidea_biosample.9.xml ==> 24/161     Meliponula sp. inBetaNo Load SRS10787318 None Load2
# Apoidea_biosample.9.xml ==> 25/161     Meliponula sp. inBetaNo Load SRS10787319 None Load2
# Apoidea_biosample.9.xml ==> 26/161     Meliponula sp. inBetaNo Load SRS10787311 None Load2
# Apoidea_biosample.9.xml ==> 27/161     Meliponula sp. inBetaNo Load SRS10787309 None Load2
# Apoidea_biosample.9.xml ==> 28/161     Meliponula sp. inBetaNo Load SRS10787308 None Load2
# Apoidea_biosample.9.xml ==> 29/161     Meliponula sp. inBetaNo Load SRS10787307 None Load2
# Apoidea_biosample.9.xml ==> 30/161     Meliponula sp. inBetaNo Load SRS10787306 None Load2
# Apoidea_biosample.9.xml ==> 31/161     Meliponula sp. inBetaNo Load SRS10787346 None Load2
# Apoidea_biosample.9.xml ==> 32/161     Meliponula sp. inBetaNo Load SRS10787345 None Load2
# Apoidea_biosample.9.xml ==> 33/161     Meliponula sp. inBetaNo Load SRS10787343 None Load2
# Apoidea_biosample.9.xml ==> 34/161     Meliponula sp. inBetaNo Load SRS10787342 None Load2
# Apoidea_biosample.9.xml ==> 35/161     Meliponula sp. inBetaNo Load SRS10787341 None Load2
# Apoidea_biosample.9.xml ==> 36/161     Meliponula sp. inBetaNo Load SRS10787340 None Load2
# Apoidea_biosample.9.xml ==> 37/161     Meliponula sp. inBetaNo Load SRS10787339 None Load2
# Apoidea_biosample.9.xml ==> 38/161     Meliponula sp. inBetaNo Load SRS10787338 None Load2
# Apoidea_biosample.9.xml ==> 39/161     Trigona hyalinata inBetaYes inBeta SRS1327300 None In beta, skip
# Apoidea_biosample.9.xml ==> 40/161     Trigona hyalinata inBetaYes inBeta SRS1327283 None In beta, skip
# Apoidea_biosample.9.xml ==> 41/161     Trigona hyalinata inBetaYes inBeta SRS1327284 None In beta, skip
# Apoidea_biosample.9.xml ==> 42/161     Trigona hyalinata inBetaYes inBeta SRS1327285 None In beta, skip
# Apoidea_biosample.9.xml ==> 43/161     Trigona hyalinata inBetaYes inBeta SRS1327286 None In beta, skip
# Apoidea_biosample.9.xml ==> 44/161     Trigona hyalinata inBetaYes inBeta SRS1327287 None In beta, skip
# Apoidea_biosample.9.xml ==> 45/161     Trigona hyalinata inBetaYes inBeta SRS1327207 None In beta, skip
# Apoidea_biosample.9.xml ==> 46/161     Trigona hyalinata inBetaYes inBeta SRS1327208 None In beta, skip
# Apoidea_biosample.9.xml ==> 47/161     Trigona hyalinata inBetaYes inBeta SRS1327209 None In beta, skip
# Apoidea_biosample.9.xml ==> 48/161     Trigona hyalinata inBetaYes inBeta SRS1327210 None In beta, skip
# Apoidea_biosample.9.xml ==> 49/161     Trigona hyalinata inBetaYes inBeta SRS1327201 None In beta, skip
# Apoidea_biosample.9.xml ==> 50/161     Trigona hyalinata inBetaYes inBeta SRS1327203 None In beta, skip
# Apoidea_biosample.9.xml ==> 51/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 52/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 53/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 54/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 55/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 56/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 57/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 58/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 59/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 60/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 61/161     Hylaeus inBetaNo Load SRS10181335 PRJNA763907 Load2
# Apoidea_biosample.9.xml ==> 62/161     Hylaeus inBetaNo Load SRS10181457 PRJNA763907 Load2
# Apoidea_biosample.9.xml ==> 63/161     Homo sapiens inBetaN/A autoNoSkip SRS9294129 PRJNA717113 On black list, skip
# Apoidea_biosample.9.xml ==> 64/161     Gorilla gorilla gorilla inBetaN/A autoNoG SRS4737215 PRJNA541574 In nonApoideaGenera, skip
# Apoidea_biosample.9.xml ==> 65/161     not applicable inBetaN/A autoNoSkip SRS3862473 PRJNA494160 On black list, skip
# Apoidea_biosample.9.xml ==> 66/161     not applicable inBetaN/A autoNoSkip SRS3862475 PRJNA494160 On black list, skip
# Apoidea_biosample.9.xml ==> 67/161     not applicable inBetaN/A autoNoSkip SRS3862490 PRJNA494160 On black list, skip
# Apoidea_biosample.9.xml ==> 68/161     not applicable inBetaN/A autoNoSkip SRS3862465 PRJNA494160 On black list, skip
# Apoidea_biosample.9.xml ==> 69/161     not applicable inBetaN/A autoNoSkip SRS3862468 PRJNA494160 On black list, skip
# Apoidea_biosample.9.xml ==> 70/161     not applicable inBetaN/A autoNoSkip SRS2201865 None On black list, skip
# Apoidea_biosample.9.xml ==> 71/161     not applicable inBetaN/A autoNoSkip SRS2201841 None On black list, skip
# Apoidea_biosample.9.xml ==> 72/161     not applicable inBetaN/A autoNoSkip SRS2201878 None On black list, skip
# Apoidea_biosample.9.xml ==> 73/161     not applicable inBetaN/A autoNoSkip SRS2201828 None On black list, skip
# Apoidea_biosample.9.xml ==> 74/161     not applicable inBetaN/A autoNoSkip SRS2201849 None On black list, skip
# Apoidea_biosample.9.xml ==> 75/161     not applicable inBetaN/A autoNoSkip SRS2201789 None On black list, skip
# Apoidea_biosample.9.xml ==> 76/161     Melissodes communis inBetaYes inBeta SRS2059779 PRJNA344894 In beta, skip
# Apoidea_biosample.9.xml ==> 77/161     Melissodes communis inBetaYes inBeta SRS2059782 PRJNA344894 In beta, skip
# Apoidea_biosample.9.xml ==> 78/161     missing inBetaN/A autoNoSkip SRS2059826 PRJNA344894 On black list, skip
# Apoidea_biosample.9.xml ==> 79/161     Melissodes communis inBetaYes inBeta SRS2059914 PRJNA344894 In beta, skip
# Apoidea_biosample.9.xml ==> 80/161     Melissodes communis inBetaYes inBeta SRS2059915 PRJNA344894 In beta, skip
# Apoidea_biosample.9.xml ==> 81/161     Bombus nevadensis inBetaYes inBeta SRS1306088 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 82/161     Bombus nevadensis inBetaYes inBeta SRS1306090 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 83/161     Bombus nevadensis inBetaYes inBeta SRS1306091 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 84/161     Bombus nevadensis inBetaYes inBeta SRS1306093 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 85/161     Bombus nevadensis inBetaYes inBeta SRS1306121 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 86/161     Bombus nevadensis inBetaYes inBeta SRS1306132 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 87/161     Bombus nevadensis inBetaYes inBeta SRS1306199 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 88/161     Bombus nevadensis inBetaYes inBeta SRS1306203 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 89/161     Bombus nevadensis inBetaYes inBeta SRS1306204 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 90/161     Bombus nevadensis inBetaYes inBeta SRS1306232 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 91/161     Bombus nevadensis inBetaYes inBeta SRS1306245 PRJNA305910 In beta, skip
# Apoidea_biosample.9.xml ==> 92/161     Megachile sp. (leafcutter bee) inBetaNo Load SRS642328 PRJNA252627 Load2
# Apoidea_biosample.9.xml ==> 93/161     Meliponula bocandei inBetaYes inBeta SRS815103 None In beta, skip
# Apoidea_biosample.9.xml ==> 94/161     Sceliphron caementarium inBetaYes inBeta SRS1269004 PRJNA290090 In beta, skip
# Apoidea_biosample.9.xml ==> 95/161     Bombus vestalis inBetaYes inBeta SRS5849777 None In beta, skip
# Apoidea_biosample.9.xml ==> 96/161     Felis silvestris catus inBetaN/A autoNoSkip SRS4028792 PRJNA504021 On black list, skip
# Apoidea_biosample.9.xml ==> 97/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 98/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 99/161     Homo sapiens inBetaN/A autoNoSkip None PRJNA287625 On black list, skip
# Apoidea_biosample.9.xml ==> 100/161     not applicable inBetaN/A autoNoSkip SRS3549609 PRJNA480840 On black list, skip
# Apoidea_biosample.9.xml ==> 101/161     not applicable inBetaN/A autoNoSkip SRS3549611 PRJNA480840 On black list, skip
# Apoidea_biosample.9.xml ==> 102/161     not applicable inBetaN/A autoNoSkip SRS3549639 PRJNA480840 On black list, skip
# Apoidea_biosample.9.xml ==> 103/161     Lasioglossum mediterraneum inBetaYes inBeta SRS2497692 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 104/161     Halictus scabiosae inBetaYes inBeta SRS2497699 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 105/161     Halictus scabiosae inBetaYes inBeta SRS2497829 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 106/161     Halictus scabiosae inBetaYes inBeta SRS2497760 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 107/161     Halictus scabiosae inBetaYes inBeta SRS2497732 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 108/161     Halictus scabiosae inBetaYes inBeta SRS2497767 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 109/161     Lasioglossum interruptum inBetaYes inBeta SRS2497768 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 110/161     Lasioglossum interruptum inBetaYes inBeta SRS2497765 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 111/161     Halictus scabiosae inBetaYes inBeta SRS2497800 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 112/161     Halictus scabiosae inBetaYes inBeta SRS2497880 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 113/161     Halictus scabiosae inBetaYes inBeta SRS2497876 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 114/161     Halictus scabiosae inBetaYes inBeta SRS2497919 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 115/161     Halictus scabiosae inBetaYes inBeta SRS2497968 PRJNA402054 In beta, skip
# Apoidea_biosample.9.xml ==> 116/161     Bombus nevadensis inBetaNo autoNoSRA None None autoNoSRA, skip
# Apoidea_biosample.9.xml ==> 117/161     Bombus nevadensis inBetaNo autoNoSRA None None autoNoSRA, skip
# Apoidea_biosample.9.xml ==> 118/161     Sceliphron caementarium inBetaNo autoNoSRA None PRJNA290090 autoNoSRA, skip
# Apoidea_biosample.9.xml ==> 119/161     Bombus nevadensis inBetaNo autoNoSRA None PRJNA323464 autoNoSRA, skip
# Apoidea_biosample.9.xml ==> 120/161     Bombus nevadensis inBetaNo autoNoSRA None PRJNA323464 autoNoSRA, skip
# Apoidea_biosample.9.xml ==> 121/161     Bombus nevadensis inBetaNo autoNoSRA None PRJNA323464 autoNoSRA, skip
# Apoidea_biosample.9.xml ==> 122/161     Nomada ferruginata inBetaYes inBeta SRS1466458 None In beta, skip
# Apoidea_biosample.9.xml ==> 123/161     Nomada panzeri inBetaYes inBeta SRS1466456 None In beta, skip
# Apoidea_biosample.9.xml ==> 124/161     Nomada flava inBetaYes inBeta SRS1466454 None In beta, skip
# Apoidea_biosample.9.xml ==> 125/161     Nomada leucophthalma inBetaYes inBeta SRS1466452 None In beta, skip
# Apoidea_biosample.9.xml ==> 126/161     Paratrigona lineata inBetaYes inBeta SRS1327305 None In beta, skip
# Apoidea_biosample.9.xml ==> 127/161     Paratrigona lineata inBetaYes inBeta SRS1327306 None In beta, skip
# Apoidea_biosample.9.xml ==> 128/161     Paratrigona lineata inBetaYes inBeta SRS1327307 None In beta, skip
# Apoidea_biosample.9.xml ==> 129/161     Paratrigona lineata inBetaYes inBeta SRS1327219 None In beta, skip
# Apoidea_biosample.9.xml ==> 130/161     Paratrigona lineata inBetaYes inBeta SRS1327220 None In beta, skip
# Apoidea_biosample.9.xml ==> 131/161     Paratrigona lineata inBetaYes inBeta SRS1327214 None In beta, skip
# Apoidea_biosample.9.xml ==> 132/161     Paratrigona lineata inBetaYes inBeta SRS1327216 None In beta, skip
# Apoidea_biosample.9.xml ==> 133/161     Trigona hyalinata inBetaYes inBeta SRS1327206 None In beta, skip
# Apoidea_biosample.9.xml ==> 134/161     Trigona hyalinata inBetaYes inBeta SRS1327199 None In beta, skip
# Apoidea_biosample.9.xml ==> 135/161     Trigona hyalinata inBetaYes inBeta SRS1327200 None In beta, skip
# Apoidea_biosample.9.xml ==> 136/161     Trigona hyalinata inBetaYes inBeta SRS1327202 None In beta, skip
# Apoidea_biosample.9.xml ==> 137/161     Paratrigona lineata inBetaYes inBeta SRS1326420 None In beta, skip
# Apoidea_biosample.9.xml ==> 138/161     Paratrigona lineata inBetaYes inBeta SRS1326421 None In beta, skip
# Apoidea_biosample.9.xml ==> 139/161     Paratrigona lineata inBetaYes inBeta SRS1327066 None In beta, skip
# Apoidea_biosample.9.xml ==> 140/161     Paratrigona lineata inBetaYes inBeta SRS1327064 None In beta, skip
# Apoidea_biosample.9.xml ==> 141/161     Trigona hyalinata inBetaYes inBeta SRS1326403 None In beta, skip
# Apoidea_biosample.9.xml ==> 142/161     Trigona hyalinata inBetaYes inBeta SRS1326402 None In beta, skip
# Apoidea_biosample.9.xml ==> 143/161     Trigona hyalinata inBetaYes inBeta SRS1326401 None In beta, skip
# Apoidea_biosample.9.xml ==> 144/161     Megachile sp. (policaris) inBetaNo Load SRS947788 None Load2
# Apoidea_biosample.9.xml ==> 145/161     Megachile sp. (policaris) inBetaNo Load SRS947667 None Load2
# Apoidea_biosample.9.xml ==> 146/161     Megachile sp. (policaris) inBetaNo Load SRS947674 None Load2
# Apoidea_biosample.9.xml ==> 147/161     Megachile sp. (policaris) inBetaNo Load SRS947675 None Load2
# Apoidea_biosample.9.xml ==> 148/161     Megachile sp. (policaris) inBetaNo Load SRS947676 None Load2
# Apoidea_biosample.9.xml ==> 149/161     Megachile sp. (policaris) inBetaNo Load SRS947666 None Load2
# Apoidea_biosample.9.xml ==> 150/161     Megachile sp. (policaris) inBetaNo Load SRS947656 None Load2
# Apoidea_biosample.9.xml ==> 151/161     Megachile sp. inBetaNo Load SRS947663 None Load2
# Apoidea_biosample.9.xml ==> 152/161     Megachile sp. (policaris) inBetaNo Load SRS947664 None Load2
# Apoidea_biosample.9.xml ==> 153/161     Megachile sp. (policaris) inBetaNo Load SRS947665 None Load2
# Apoidea_biosample.9.xml ==> 154/161     Megachile sp. (policaris) inBetaNo Load SRS947637 None Load2
# Apoidea_biosample.9.xml ==> 155/161     Megachile sp. (policaris) inBetaNo Load SRS947640 None Load2
# Apoidea_biosample.9.xml ==> 156/161     Megachile sp. (policaris) inBetaNo Load SRS947641 None Load2
# Apoidea_biosample.9.xml ==> 157/161     Megachile sp. (policaris) inBetaNo Load SRS947635 None Load2
# Apoidea_biosample.9.xml ==> 158/161     Megachile sp. (policaris) inBetaNo Load SRS947642 None Load2
# Apoidea_biosample.9.xml ==> 159/161     Megachile sp. (policaris) inBetaNo Load SRS947643 None Load2
# Apoidea_biosample.9.xml ==> 160/161     Megachile sp. (policaris) inBetaNo Load SRS947644 None Load2
# Apoidea_biosample.9.xml ==> 161/161     Megachile sp. (policaris) inBetaNo Load SRS947646 None Load2
# Drop1 done.

# %%
# Step Drop2, run on *Drop.csv files and get all in one csv

listF = list(pathlib.Path(dnOut).glob('*Drop.csv'))
for f_name in listF: #os.listdir(dnIn + '.xml'):     #print(f_name)
        dn0, fn0  = os.path.split(f_name)
        if (fn0.startswith('Apoidea_biosample_')): #_2_
                fn = dn0 + '\\' + fn0  
                df = pd.read_csv(fn)
                s0 = len(df.index)
                print('--', fn, str(s0)); 
                #df = df_.reindex(columns=['host', 'taxid', 'in_beta', 'load', 'has_sra', 'has_proj', '@access', '@publication_date', '@last_update', '@submission_date', '@id', '@accession', 'Ids', 'Description', 'Owner', 'Models', 'Package', 'Attributes', 'Links', 'Status'])
                for index, row0 in df.iterrows(): #iterrows(): #index = row0.Index   print(row0._7)
                        row = row0
                        str1 = row['host']
                        strSkip = ''
                        if type(str1) == 'str': 
                                print('Not string host:',str1) #error host
                                continue
                        
                        #if host is in updated white list, update taxid
                        if row['taxid'] == 'Load3':
                                v2 = 'noTaxid'
                                v1 = whiteL.loc[whiteL['host'] == str1.lower()]
                                v2 = v1['taxid'].tolist() #print(v2)
                                if v2:
                                        s1 = str(v2[0])
                                        df.at[index,'taxid'] = s1
                                        df.at[index,'load'] = 'Load56'
                                        strSkip = 'Add host, taxid found' #print(v2)
                                elif re.match(auto_no, str1.casefold()): 
                                        #check if host exist in autoNo (black list), then drop
                                        if row['in_beta'] == 'inBeta': print('Warning!!!')
                                        #if row['host'] == 'Ceratina':  print('Warning!!!'); break
                                        df.at[index,'taxid'] = 'NotApoidea'
                                        df.at[index,'load'] = 'autoNoSkip'
                                        df.at[index,'in_beta'] = 'inBetaN/A'
                                        strSkip = 'On black list, skip'
                                print(str(index + 1) + '/' + str(s0) + '    ', row['host'],s1,row['in_beta'],row['taxid'],row['load'],row['has_sra'],row['has_proj'],strSkip)                     
                        row0 = row
                df.to_csv(fn + 'Drop2.csv', encoding='utf-8', index=False) 
#combine all files in one file
listCSVs = sorted(glob.glob(dnOut + '*Drop2.csv'))
combined_csv = pd.concat([pd.read_csv(f) for f in listCSVs ])
combined_csv.to_csv( dnOut + "combinedAll_missed.csv", index=False, encoding='utf-8-sig')
# Out:
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_10_xmlDrop.csv 57
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_11_xmlDrop.csv 0
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_12_xmlDrop.csv 403
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_13_xmlDrop.csv 20
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_14_xmlDrop.csv 27
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_15_xmlDrop.csv 2
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_16_xmlDrop.csv 295
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_17_xmlDrop.csv 806
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_18_xmlDrop.csv 12
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_19_xmlDrop.csv 231
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_1_xmlDrop.csv 20
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_20_xmlDrop.csv 0
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_21_xmlDrop.csv 236
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_22_xmlDrop.csv 5
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_24_xmlDrop.csv 24
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_25_xmlDrop.csv 456
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_26_xmlDrop.csv 4
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_2_xmlDrop.csv 137
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_3_xmlDrop.csv 271
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_4_xmlDrop.csv 23
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_5_xmlDrop.csv 19
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_6_xmlDrop.csv 19
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_7_xmlDrop.csv 19
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_8_xmlDrop.csv 22
# -- D:\arh2021\_poGc21\bPortal\Apoidea2Mar22\biosample_XMLtoCSVs\Apoidea_biosample_9_xmlDrop.csv 52
